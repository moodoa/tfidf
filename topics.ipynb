# %%
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
from sqlalchemy.orm import scoped_session, sessionmaker
import cymysql
import pandas as pd
ENGINE = create_engine('postgresql://weed:jokerdance@35.194.182.187/recom',encoding='utf-8')

result = ENGINE.execute("SELECT * FROM crowd_sourcing_posts_with_topics;") 
res = result.fetchall()

# %%
topic_list = []
for w in res:
    test = str(w)
    test = test[2:]
    test = test[:-3]
    topic_list.append(test)

# %%
len(topic_list)
# Out:
# 11922

# %%
len(set(topic_list))
# Out:
# 7279

# %%
insert_dic = set(topic_list)

# %%
insert_list=[]
for w in insert_dic:
    insert_list.append(w+'\n')

# %%
len(insert_list)
# Out:
# 7279

# %%
with open('testdic.txt','r',encoding='utf-8') as file:
    for w in file:
        if w in insert_list:
            insert_list.remove(w)

# %%
with open('topic.txt','a',encoding='utf-8') as file:
    for w in topic_list:
        file.write(w+'\n')

# %%
len(insert_list)
# Out:
# 4935

# %%
with open('testdic.txt','a',encoding='utf-8') as file:
    for w in insert_list:
        file.write(w)

# %%
res[::-1]
# Out:
# [(232983616, '泥糊', 'weed', datetime.date(2020, 2, 1)),
#  (232983616, '碎粒', 'weed', datetime.date(2020, 2, 1)),
#  (232983616, '寶寶', 'weed', datetime.date(2020, 2, 1)),
#  (232983605, '口紅', 'weed', datetime.date(2020, 2, 1)),
#  (232983605, 'ga206', 'weed', datetime.date(2020, 2, 1)),
#  (232983595, '讓我', 'weed', datetime.date(2020, 2, 1)),
#  (232983595, '台灣', 'weed', datetime.date(2020, 2, 1)),
#  (232983595, '姊姊', 'weed', datetime.date(2020, 2, 1)),
#  (232983586, '牙齒矯正', 'weed', datetime.date(2020, 2, 1)),
#  (232983586, '牙套', 'weed', datetime.date(2020, 2, 1)),
#  (232983564, 'realme', 'weed', datetime.date(2020, 2, 1)),
#  (232983564, '比較', 'weed', datetime.date(2020, 2, 1)),
#  (232983564, '遊戲', 'weed', datetime.date(2020, 2, 1)),
#  (232983564, '過年', 'weed', datetime.date(2020, 2, 1)),
#  (232983553, '武漢肺炎', 'weed', datetime.date(2020, 2, 1)),
#  (232983553, '口罩', 'weed', datetime.date(2020, 2, 1)),
#  (232983547, '神魔之塔', 'weed', datetime.date(2020, 2, 1)),
# ...

# %%
from collections import Counter

# %%
c = Counter(topic_list)

# %%
counts = c.most_common()

# %%
topic_df = pd.DataFrame(counts)

# %%
topic_df.columns = ['topic','counts']

# %%
topic_df
# Out:
#                     topic  counts
# 0                2020總統大選     279
# 1                     韓國瑜     172
# 2                       貓     158
# 3                     蔡英文     138
# 4                    武漢肺炎      74
# 5                      韓粉      60
# 6                     民進黨      58
# 7                     國民黨      40
# 8                      蝦皮      37
# 9                    問卷調查      34
# 10                    想見你      31
# 11                     美甲      29
# 12                    謝和弦      29
# 13                    柯文哲      28
# 14                   返鄉投票      27
# 15                   時代力量      26
# 16                   傳說對決      26
# 17                    民眾黨      26
# 18                     唇膏      25
# 19                     中國      24
# 20                      狗      23
# 21                   人像攝影      22
# 22                    黃國昌      22
# 23                     投票      21
# 24                    轉學考      21
# 25                   nike      20
# ...

# %%
topic_df[topic_df['topic'] == '瑪爾濟斯']
# Out:
#     topic  counts
# 416  瑪爾濟斯       3
